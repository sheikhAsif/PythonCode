# %%
#Blood group donor-acceptor checker
ans = 'y'
while (ans == 'y' ) : 
    print("\t\tWelcome To The Blood Donor-Acceptor checker\n")
    print("Blood Groups are:\n\t1. A+\t\t5. A-\n\t2. O+\t\t6. O-\n\t3. B+\t\t7. B-\n\t4. AB+\t\t8. AB-\n")
    print("Enter any one option(1 or 2) :\n\t1.You Want To Check Whom You Can Donate?\n\t2.You Want To Check From Whom You Can Accept?")

    response = int(input())

    if response == 1 :
        bg = input("Enter your blood group: ")
        bg = bg.upper()
        if bg == "A+" :
            print("You Can Give Blood To:\n\t\tA+ and AB+.")
            ans = input("Do You Want To Check again(y or n) : ")
            if ans == "n"  :
                break       
        elif bg == "O+" :
            print("You Can Give Blood To:\n\t\tO+ , A+ , B+ and AB+.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "B+" :
            print("You Can Give Blood To:\n\t\tB+ and AB+.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "AB+" :
            print("You Can Give Blood To:\n\t\tAB+.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "A-" :
            print("You Can Give Blood To:\n\t\tA+ , A- , AB+ and AB-.").lower()
            ans = input("Do You Want To Check again(y or n) : ")
            if ans == "n"  :
                break  
        elif bg == "O-" :
            print("You Can Give Blood To:\n\t\tO+ , A+ , B+ , O- , A- , B- , AB+ and AB-(Everyone).")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "B-" :
            print("You Can Give Blood To:\n\t\tB+ , B- , AB+ and AB-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "AB-" :
            print("You Can Give Blood To:\n\t\tAB+ and AB-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        else :
            print("You Have Entered Wrong Value.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
    elif response == 2 :
        bg = input("Enter your blood group: ")
        bg = bg.upper()
        if bg == "A+" :
            print("You Can Receive Blood From:\n\t\tA+ , A- , O+ and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "O+" :
            print("You Can Receive Blood From:\n\t\tO+ and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "B+" :
            print("You Can Receive Blood From:\n\t\tB+ , B- , O+ and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "AB+" :
            print("You Can Receive Blood From:\n\t\tEveryone.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break 
        elif bg == "A-" :
            print("You Can Receive Blood From:\n\t\tA- and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        elif bg == "O-" :
            print("You Can Receive Blood From:\n\t\tO-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break 
        elif bg == "B-" :
            print("You Can Receive Blood From:\n\t\tB- and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break
        elif bg == "AB-" :
            print("You Can Receive Blood From:\n\t\tAB+ , A- , B-and O-.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break  
        else :
            print("You Have Entered Wrong Value.")
            ans = input("Do You Want To Check again(y or n) : ").lower()
            if ans == "n"  :
                break 
    
print("\nThank You..")
# Out:
# 		Welcome To The Blood Donor-Acceptor checker
#
# Blood Groups are:
# 	1. A+		5. A-
# 	2. O+		6. O-
# 	3. B+		7. B-
# 	4. AB+		8. AB-
#
# Enter any one option(1 or 2) :
# 	1.You Want To Check Whom You Can Donate?
# 	2.You Want To Check From Whom You Can Accept?
# 1
# Enter your blood group: a-
# You Can Give Blood To:
# 		A+ , A- , AB+ and AB-.
# Do You Want To Check again(y or n) : n
#
# Thank You..
